# %% [markdown]
# ## Statistical analysis of dairy sector

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import sklearn
import matplotlib.pyplot as plt
from matplotlib import rcParams
from pandas.plotting import scatter_matrix
#import statistics as stats
import scipy.stats as stats
from statsmodels.stats import weightstats
from scipy.stats import poisson
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import r2_score
import warnings
from sklearn.feature_selection import RFE

warnings.filterwarnings('ignore') # supress warnings

# %%
# import cleaned data set for EDA section.
nldf = pd.read_csv('NL_Milk_supply_and_dairy_production_Cleaned.csv')
iedf = pd.read_csv('IE_Intake of Cows Milk Cleaned.csv')

# %%
iedf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  130 non-null    int64
#  1   date        130 non-null    object
#  2   milk        130 non-null    float64
#  3   fat         130 non-null    float64
#  4   pro         130 non-null    float64
#  5   year        130 non-null    int64
#  6   month       130 non-null    object
# dtypes: float64(3), int64(2), object(2)
# memory usage: 7.2+ KB

# %%
iedf['date'] =  pd.to_datetime(iedf['date'])

# %%
#iedf['months'] = iedf['date'].apply(lambda x:x.strftime('%B'))
#iedf['month'] = iedf['date'].dt.month()
#iedf['month'] = pd.DatetimeIndex(iedf['date']).month
iedf = iedf.drop(['Unnamed: 0'], axis=1)

# %%
iedf.head()
# Out:
#         date   milk   fat   pro  year     month
# 0 2012-01-01  133.3  3.98  3.25  2012   January
# 1 2012-02-01  236.6  4.06  3.24  2012  February
# 2 2012-03-01  473.0  3.99  3.22  2012     March
# 3 2012-04-01  637.3  3.81  3.32  2012     April
# 4 2012-05-01  735.0  3.75  3.34  2012       May

# %%
nldf.head()
# Out:
#    Unnamed: 0        date       milk   fat   pro   butter   cheese  \
# 0         208  2012-01-01  1023015.0  4.48  3.57  12917.0  65821.0
# 1         209  2012-02-01   944916.0  4.59  3.60  12386.0  61730.0
# 2         210  2012-03-01  1037702.0  4.46  3.53  13818.0  66103.0
# 3         211  2012-04-01   998315.0  4.43  3.52  11894.0  63307.0
# 4         212  2012-05-01  1024366.0  4.32  3.47  14113.0  65235.0
#
#    powder tot  powder who  powder skim      con whey  year     month
# 0     18948.0     11954.0       6994.0  29767.0    .  2012   january
# 1     14905.0      9372.0       5533.0  30523.0    .  2012  february
# 2     17169.0     11442.0       5728.0  27959.0    .  2012     march
# 3     16903.0     10860.0       6043.0  32211.0    .  2012     april
# 4     16033.0     10082.0       5951.0  31201.0    .  2012       may

# %%
nldf = nldf.drop(['Unnamed: 0','butter','cheese','powder tot','powder who','powder skim','con','whey'], axis=1)

# %%
nldf.head()
# Out:
#          date       milk   fat   pro  year     month
# 0  2012-01-01  1023015.0  4.48  3.57  2012   january
# 1  2012-02-01   944916.0  4.59  3.60  2012  february
# 2  2012-03-01  1037702.0  4.46  3.53  2012     march
# 3  2012-04-01   998315.0  4.43  3.52  2012     april
# 4  2012-05-01  1024366.0  4.32  3.47  2012       may

# %%
iedf.set_index('date')
nldf.set_index('date')
# Out:
#                  milk   fat   pro  year      month
# date
# 2012-01-01  1023015.0  4.48  3.57  2012    january
# 2012-02-01   944916.0  4.59  3.60  2012   february
# 2012-03-01  1037702.0  4.46  3.53  2012      march
# 2012-04-01   998315.0  4.43  3.52  2012      april
# 2012-05-01  1024366.0  4.32  3.47  2012        may
# ...               ...   ...   ...   ...        ...
# 2022-06-01  1148199.0  4.25  3.48  2022       june
# 2022-07-01  1164104.0  4.20  3.45  2022       july
# 2022-08-01  1147712.0  4.21  3.46  2022     august
# 2022-09-01  1105982.0  4.36  3.53  2022  september
# 2022-10-01  1139853.0  4.49  3.63  2022    october
#
# [130 rows x 5 columns]

# %%
iedfm = iedf.groupby('month')
nldfm = nldf.groupby('month')
#iedfm.head()

# %%
nldfm.head()
# Out:
#           date       milk   fat   pro  year      month
# 0   2012-01-01  1023015.0  4.48  3.57  2012    january
# 1   2012-02-01   944916.0  4.59  3.60  2012   february
# 2   2012-03-01  1037702.0  4.46  3.53  2012      march
# 3   2012-04-01   998315.0  4.43  3.52  2012      april
# 4   2012-05-01  1024366.0  4.32  3.47  2012        may
# 5   2012-06-01   984161.0  4.25  3.45  2012       june
# 6   2012-07-01   976527.0  4.20  3.43  2012       july
# 7   2012-08-01   948758.0  4.21  3.44  2012     august
# 8   2012-09-01   907765.0  4.32  3.52  2012  september
# 9   2012-10-01   931754.0  4.49  3.60  2012    october
# 10  2012-11-01   914765.0  4.53  3.61  2012   november
# 11  2012-12-01   983403.0  4.54  3.60  2012   december
# 12  2013-01-01  1021883.0  4.51  3.56  2013    january
# 13  2013-02-01   940192.0  4.54  3.57  2013   february
# 14  2013-03-01  1039943.0  4.56  3.57  2013      march
# 15  2013-04-01  1013705.0  4.50  3.53  2013      april
# 16  2013-05-01  1081899.0  4.34  3.49  2013        may
# 17  2013-06-01  1017690.0  4.27  3.46  2013       june
# 18  2013-07-01  1049763.0  4.18  3.42  2013       july
# 19  2013-08-01  1043246.0  4.17  3.42  2013     august
# 20  2013-09-01   986107.0  4.30  3.52  2013  september
# 21  2013-10-01  1011405.0  4.42  3.60  2013    october
# 22  2013-11-01   970148.0  4.50  3.61  2013   november
# 23  2013-12-01  1036711.0  4.51  3.59  2013   december
# 24  2014-01-01  1073921.0  4.46  3.54  2014    january
# 25  2014-02-01   980185.0  4.47  3.53  2014   february
# 26  2014-03-01  1084192.0  4.44  3.51  2014      march
# 27  2014-04-01  1081728.0  4.37  3.48  2014      april
# 28  2014-05-01  1094417.0  4.28  3.48  2014        may
# 29  2014-06-01  1045568.0  4.18  3.45  2014       june
# 30  2014-07-01  1051622.0  4.15  3.41  2014       july
# 31  2014-08-01  1036470.0  4.18  3.45  2014     august
# 32  2014-09-01   998215.0  4.26  3.54  2014  september
# 33  2014-10-01  1015984.0  4.36  3.57  2014    october
# 34  2014-11-01   977125.0  4.44  3.60  2014   november
# 35  2014-12-01  1033595.0  4.52  3.60  2014   december
# 36  2015-01-01  1051819.0  4.51  3.56  2015    january
# 37  2015-02-01   954307.0  4.52  3.55  2015   february
# 38  2015-03-01  1061825.0  4.49  3.49  2015      march
# 39  2015-04-01  1100420.0  4.42  3.53  2015      april
# 40  2015-05-01  1166526.0  4.28  3.51  2015        may
# 41  2015-06-01  1145600.0  4.24  3.50  2015       june
# 42  2015-07-01  1162176.0  4.17  3.43  2015       july
# 43  2015-08-01  1147059.0  4.21  3.46  2015     august
# 44  2015-09-01  1091193.0  4.34  3.54  2015  september
# 45  2015-10-01  1132078.0  4.45  3.63  2015    october
# 46  2015-11-01  1112571.0  4.48  3.60  2015   november
# 47  2015-12-01  1205300.0  4.47  3.57  2015   december
# 48  2016-01-01  1214745.0  4.51  3.57  2016    january
# 49  2016-02-01  1161335.0  4.53  3.57  2016   february
# 50  2016-03-01  1239907.0  4.55  3.59  2016      march
# 51  2016-04-01  1218592.0  4.47  3.54  2016      april
# 52  2016-05-01  1263123.0  4.35  3.50  2016        may
# 53  2016-06-01  1199718.0  4.24  3.43  2016       june
# 54  2016-07-01  1218901.0  4.19  3.45  2016       july
# 55  2016-08-01  1202383.0  4.22  3.45  2016     august
# 56  2016-09-01  1133945.0  4.22  3.47  2016  september
# 57  2016-10-01  1154341.0  4.44  3.61  2016    october
# 58  2016-11-01  1112734.0  4.55  3.67  2016   november
# 59  2016-12-01  1204713.0  4.58  3.65  2016   december

# %%
iedfm.describe()
# Out:
#            milk                                                            \
#           count        mean         std    min      25%     50%       75%
# month
# April      11.0  835.327273  165.265187  568.7  728.900  823.10   968.000
# August     11.0  754.373636  133.215162  546.8  651.050  786.60   855.200
# December   10.0  202.300000   49.192931  137.6  168.175  193.55   254.225
# February   11.0  281.636364   54.875172  214.0  229.750  287.10   317.650
# January    11.0  152.790909   24.444732  114.8  132.650  148.70   175.750
# July       11.0  836.263636  147.423623  609.8  728.450  853.40   964.100
# June       11.0  889.954545  142.472968  684.3  775.800  917.90  1016.000
# March      11.0  616.500000  139.169249  454.0  471.850  620.90   717.200
# May        11.0  962.054545  164.753855  733.2  830.300  993.10  1093.750
# November   10.0  360.250000   90.354084  227.6  291.575  364.35   441.875
# October    11.0  547.371818  110.820666  364.2  463.200  536.30   644.400
# September  11.0  639.792727  117.148684  446.6  551.500  654.00   723.650
#
#                      fat            ...    pro        year                    \
#                max count      mean  ...    75%   max count    mean       std
# month                               ...
# April      1060.50  11.0  3.930909  ...  3.415  3.45  11.0  2017.0  3.316625
# August      919.01  11.0  4.080000  ...  3.540  3.57  11.0  2017.0  3.316625
# December    258.80  10.0  4.457000  ...  3.650  3.72  10.0  2016.5  3.027650
# February    367.50  11.0  4.232727  ...  3.400  3.47  11.0  2017.0  3.316625
# January     183.30  11.0  4.190909  ...  3.445  3.51  11.0  2017.0  3.316625
# July       1022.80  11.0  3.917273  ...  3.445  3.51  11.0  2017.0  3.316625
# June       1067.30  11.0  3.853636  ...  3.455  3.47  11.0  2017.0  3.316625
# March       829.70  11.0  4.160909  ...  3.305  3.33  11.0  2017.0  3.316625
# May        1181.00  11.0  3.815455  ...  3.450  3.49  11.0  2017.0  3.316625
# November    465.90  10.0  4.668000  ...  3.850  3.94  10.0  2016.5  3.027650
# October     698.49  11.0  4.576364  ...  3.950  3.99  11.0  2017.0  3.316625
# September   785.62  11.0  4.323636  ...  3.765  3.79  11.0  2017.0  3.316625
#
#
#               min      25%     50%      75%     max
# month
# April      2012.0  2014.50  2017.0  2019.50  2022.0
# August     2012.0  2014.50  2017.0  2019.50  2022.0
# December   2012.0  2014.25  2016.5  2018.75  2021.0
# February   2012.0  2014.50  2017.0  2019.50  2022.0
# January    2012.0  2014.50  2017.0  2019.50  2022.0
# July       2012.0  2014.50  2017.0  2019.50  2022.0
# June       2012.0  2014.50  2017.0  2019.50  2022.0
# March      2012.0  2014.50  2017.0  2019.50  2022.0
# May        2012.0  2014.50  2017.0  2019.50  2022.0
# November   2012.0  2014.25  2016.5  2018.75  2021.0
# October    2012.0  2014.50  2017.0  2019.50  2022.0
# September  2012.0  2014.50  2017.0  2019.50  2022.0
#
# [12 rows x 32 columns]

# %%
iiedfm['milk'].agg([np.sum, np.mean, np.std])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 iiedfm['milk'].agg([np.sum, np.mean, np.std])
#
# NameError: name 'iiedfm' is not defined

# %%
nldfm['milk'].agg([np.sum, np.mean, np.std])

# %%
rcParams['figure.figsize'] = 15,8
ax = sns.boxplot(x='month',y = 'pro', data = iedf, whis = 10)
ax2 = ax.twinx()
ax =sns.lineplot(x='month', y ='milk',data = iedf, dashes=lab_mon).set(title='IE Milk Volume V % Protein')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [15], in <cell line: 4>()
#       2 ax = sns.boxplot(x='month',y = 'pro', data = iedf, whis = 10)
#       3 ax2 = ax.twinx()
# ----> 4 ax =sns.lineplot(x='month', y ='milk',data = iedf, dashes=lab_mon).set(title='IE Milk Volume V % Protein')
#
# NameError: name 'lab_mon' is not defined

# %%
ax = sns.boxplot(x='month' , y = 'fat', data = iedf, whis = 10)
ax2 = ax.twinx()
sns.lineplot(x='month', y ='milk',data = iedf).set(title='IE Milk Volume V % Fat')
#plt.savefig("ff_day_box_plot.png", dpi=300)

# %%
ax = sns.boxplot(x='month' , y = 'fat', data = nldf, whis = 10)

ax2 = ax.twinx()
ax = sns.lineplot(x='month', y ='milk',data = nldf).set(title='NL Milk Volume V % Fat')
#plt.savefig("ff_day_box_plot.png", dpi=300)

# %%
ax = sns.boxplot(x='month' , y = 'pro', data = nldf, whis = 10)

ax2 = ax.twinx()
ax = sns.lineplot(x='month', y ='milk',data = nldf).set(title='NL Milk Volume V % Protein')
#plt.savefig("ff_day_box_plot.png", dpi=300)

# %%
# Descriptive Statistics - summerise the dataset, help id chosen model
ax = sns.histplot(iedf.fat)
ax.set(xlabel='% Fat', ylabel='Count', title ='IE % Fat distribution')
# Out:
# [Text(0.5, 0, '% Fat'),
#  Text(0, 0.5, 'Count'),
#  Text(0.5, 1.0, 'IE % Fat distribution')]

# %%
# Descriptive Statistics - summerise the dataset, help id chosen model
ax = sns.histplot(nldf.fat)
ax.set(xlabel='% Fat', ylabel='Count', title ='NL % Fat distribution')
# Out:
# [Text(0.5, 0, '% Fat'),
#  Text(0, 0.5, 'Count'),
#  Text(0.5, 1.0, 'NL % Fat distribution')]

# %%
# Descriptive Statistics - summerise the dataset, help id chosen model
ax = sns.histplot(iedf.pro)
ax.set(xlabel='% Protein', ylabel='Count', title ='% Protein distribution')
# Out:
# [Text(0.5, 0, '% Protein'),
#  Text(0, 0.5, 'Count'),
#  Text(0.5, 1.0, '% Protein distribution')]

# %%
# Descriptive Statistics - summerise the dataset, help id chosen model
ax = sns.histplot(nldf.pro)
ax.set(xlabel='% Protein', ylabel='Count', title ='% Protein distribution')
# Out:
# [Text(0.5, 0, '% Protein'),
#  Text(0, 0.5, 'Count'),
#  Text(0.5, 1.0, '% Protein distribution')]

# %%
# Inferential statistics to gain insights on posibble population values
X = iedf['pro']; X
# Out:
# 0      3.25
# 1      3.24
# 2      3.22
# 3      3.32
# 4      3.34
#        ...
# 125    3.47
# 126    3.47
# 127    3.53
# 128    3.75
# 129    3.97
# Name: pro, Length: 130, dtype: float64

# %%
#H0 : u = 3.44
#H1 : u =! 3.44
#stats.ttest_1samp(X,mu of H0)
stats.ttest_1samp(X,3)
# Out:
# Ttest_1sampResult(statistic=27.130417961012316, pvalue=3.748513030027395e-55)

# %%
#inferential stats.  find similarities with parametric and non paremetric t-test, analysis of variance, wilcoxon , chi
# hypot and conclusion must be clearly stated.   
# use 5 diferent inferential stats

# %%
# review outcome to deepen understanding , indicate challanges
